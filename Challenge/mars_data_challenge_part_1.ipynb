# %%
# Scraping table with Splinter and Beautiful Soup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager
import json

# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# Visit the Mars Facts site
url = 'https://redplanetscience.com'
browser.visit(url)

# Assigned HTML content to the html variable
html = browser.html
# Beautiful Soup then parses the HTML content.
html_soup = soup(html, 'html.parser')

# %%
# articles = html_soup.find_all('div', class_='list_text')
articles = html_soup.find('div', id='news', class_='container')
articles
# Out:
# <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8737_24760_PIA23492-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">November 23, 2022</div>
# <div class="content_title">NASA Establishes Board to Initially Review Mars Sample Return Plans</div>
# <div class="article_teaser_body">The board will assist with analysis of current plans and goals for one of the most difficult missions humanity has ever undertaken.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8692_PIA23920-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">November 22, 2022</div>
# ...

# %%
list_text = articles.find_all('div', class_='list_text')
list_text
# Out:
# [<div class="list_text">
#  <div class="list_date">November 23, 2022</div>
#  <div class="content_title">NASA Establishes Board to Initially Review Mars Sample Return Plans</div>
#  <div class="article_teaser_body">The board will assist with analysis of current plans and goals for one of the most difficult missions humanity has ever undertaken.</div>
#  </div>,
#  <div class="list_text">
#  <div class="list_date">November 22, 2022</div>
#  <div class="content_title">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</div>
#  <div class="article_teaser_body">Learn more about the agency's next Red Planet mission during a live event on June 17.</div>
#  </div>,
#  <div class="list_text">
#  <div class="list_date">November 21, 2022</div>
#  <div class="content_title">NASA's InSight 'Hears' Peculiar Sounds on Mars</div>
#  <div class="article_teaser_body">Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.</div>
#  </div>,
# ...

# %%
news_list = []

# %%
for article in list_text:
    title = article.find('div', class_='content_title').text
    preview = article.find('div', class_='article_teaser_body').text
    news_dict = {}
    news_dict["title"] = title
    news_dict["preview"] = preview
    news_list.append(news_dict)
news_list
# Out:
# [{'title': 'NASA Establishes Board to Initially Review Mars Sample Return Plans',
#   'preview': 'The board will assist with analysis of current plans and goals for one of the most difficult missions humanity has ever undertaken.'},
#  {'title': 'NASA to Hold Mars 2020 Perseverance Rover Launch Briefing',
#   'preview': "Learn more about the agency's next Red Planet mission during a live event on June 17."},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "Screening Soon: 'The Pathfinders' Trains Lens on Mars",
#   'preview': 'With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.'},
#  {'title': "NASA's Push to Save the Mars InSight Lander's Heat Probe",
# ...

# %%
# Store the scraped data in a JSON file 
print(json.dumps(news_list))
with open("outfile.json", "w") as f:
    f.write(json.dumps(news_list))
# Out:
# [{"title": "NASA Establishes Board to Initially Review Mars Sample Return Plans", "preview": "The board will assist with analysis of current plans and goals for one of the most difficult missions humanity has ever undertaken."}, {"title": "NASA to Hold Mars 2020 Perseverance Rover Launch Briefing", "preview": "Learn more about the agency's next Red Planet mission during a live event on June 17."}, {"title": "NASA's InSight 'Hears' Peculiar Sounds on Mars", "preview": "Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting."}, {"title": "Screening Soon: 'The Pathfinders' Trains Lens on Mars", "preview": "With the Mars 2020 mission ramping up, the documentary \u2014 the first of four about past JPL missions to the Red Planet to be shown at Caltech \u2014 tells a gripping backstory."}, {"title": "NASA's Push to Save the Mars InSight Lander's Heat Probe", "preview": "The scoop on the end of the spacecraft's robotic arm will be used to 'pin' the m
# ...

# %%
# End the Automated Browsing Session
browser.quit()
